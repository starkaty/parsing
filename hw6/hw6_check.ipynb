# %%
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError
from pprintpp import pprint as pp

# %% [markdown]
#     Проверка записей в базе mongoDB с помощью scrapy

# %%
client = MongoClient()
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.parser_goods

# %%
db.list_collection_names() #проверяем коллекции
# Out:
# ['castorama_ru']

# %%
print(client.list_database_names()) #проверяем базы данных
# Out:
# ['admin', 'config', 'local', 'parser_books', 'parser_goods', 'vacancy']

# %%
collection = db.castorama_ru

# %%
n_goods = len(list(collection.find()))
print(f'There are {n_goods} goods')
# Out:
# There are 42 goods

# %%
list_goods = collection.find({})
for el in list_goods:
    pp(el)
# Out:
# {
#     '_id': ObjectId('6401053179ccbace35edde2d'),
#     'link': 'https://www.castorama.ru/khanna_seryy_fasad_15kh72_mk/',
#     'name': 'Фасад для шкафа Ханна 15 х 72 см, серый',
#     'photos': [
#         'https://www.castorama.ru/upload/resize_cache/iblock/835/txd9w2o6aypf9it1ao3g9pitwl3k1qdr/80_80_1/1001469046_1.jpg',
#         'https://www.castorama.ru/upload/resize_cache/iblock/f78/rf95n5p30jg1oqrtow47ptgcjsyc47eh/80_80_1/1001469046_2.jpg',
#         'https://www.castorama.ru/upload/resize_cache/iblock/b18/3u85h2whcyvlzvc6qnnwjl98o1nectn9/80_80_1/1001469046_8.jpg',
#     ],
#     'price': 600,
# }
# {
#     '_id': ObjectId('6401056579ccbace35edde2e'),
#     'link': 'https://www.castorama.ru/kamila_belyy_fasad_80kh36_mk/',
#     'name': 'Фасад для шкафа Камила 80 х 36 см, белый',
#     'photos': [
#         'https://www.castorama.ru/upload/resize_cache/iblock/b78/gmn413zitqwjjs62z96969p0kywp577g/80_80_1/1001468926_1.jpg',
# ...
